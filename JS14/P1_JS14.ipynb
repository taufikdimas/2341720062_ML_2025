# %% [markdown]
# #JS14 - Convolutional Neural Network
#
# > Nama  :  Taufik Dimas<br>
# > NIM   : 2341720062<br>
# > Kelas : TI-3G

# %% [markdown]
# # Pratikum 1 (Klasifikasi Cat vs. Dog)
#
# > Pada praktikum ini kita akan membuat model klasifikasi CNN sederhana pada kasus citra kucing dan anjing.

# %% [markdown]
# ## Dataset
#
# > Dataset merupakan data citra anjing dan kucing yang telah dibagi menjadi data training dan data testing. Dikarenakan data cukup besar, pastikan koneksi Anda sebelum mengunduh dataset.

# %%
import gdown
import zipfile
import os

def download_and_extract(file_id, output_filename, extract_path):
    gdown.download(id=file_id, output=output_filename, quiet=True, fuzzy=True)

    try:
        with zipfile.ZipFile(output_filename, 'r') as zip_ref:
            zip_ref.extractall(extract_path)
        print(f"Berhasil diekstrak ke folder: {extract_path}")
    except zipfile.BadZipFile:
        print("Error: Bukan file zip yang valid.")
    except Exception as e:
        print(e)

FILE_ID = '1r4csjkRvnim1bV4hEmuzwjbPhSGUB4EE'
OUTPUT_FILE = 'file.zip'
EXTRACT_FOLDER = './'

download_and_extract(FILE_ID, OUTPUT_FILE, EXTRACT_FOLDER)
# Out:
# Berhasil diekstrak ke folder: ./

# %% [markdown]
# ##Langkah 1 - Import Library

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ##Langkah 2 - Pra Pengolahan Data
#
# > Pada tahap ini kita akan sedikit melakukan manipulasi pada citra yang digunakan. Manipulasi yang dilakukan diantaranya adalah normalisasi nilai piksel, koreksi kemiringan, pembesaran (zoom), dan flip.

# %% [markdown]
# ### Langkah 2.1. Pra Pengolahan Data Training

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# ### Langkah 2.2. Pra Pengolahan Data Testing

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ## Langkah 3 - Pembuatan Model CNN

# %% [markdown]
# ### Langkah 3.1.  - Inisiasi Model CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ### Langkah 3.2. - Pembuatan Layer Konvolusi 1

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ###Langkah 3.3 - Pembuatan Layer Pooling 1

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ###Langkah 3.4 - Pembuatan Layer Konvolusi 2 dan Pooling 2

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ###Langkah 3.5 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ###Langkah 3.6 - Fully Connected Layer 1 (Input)

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# ###Langkah 3.7 - Fully Connected Layer 2 (Output)

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ###Langkah 3.8 - Compile Model CNN

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ## Langkah 4 - Fit CNN

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 53s 205ms/step - accuracy: 0.5259 - loss: 0.6996 - val_accuracy: 0.6210 - val_loss: 0.6571
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 201ms/step - accuracy: 0.6141 - loss: 0.6544 - val_accuracy: 0.6835 - val_loss: 0.6096
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 51s 202ms/step - accuracy: 0.6677 - loss: 0.6069 - val_accuracy: 0.6840 - val_loss: 0.6055
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 51s 202ms/step - accuracy: 0.6804 - loss: 0.5921 - val_accuracy: 0.7020 - val_loss: 0.5850
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 51s 203ms/step - accuracy: 0.7197 - loss: 0.5436 - val_accuracy: 0.7150 - val_loss: 0.5574
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 81s 201ms/step - accuracy: 0.7427 - loss: 0.5186 - val_accuracy: 0.7530 - val_loss: 0.5178
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 201ms/step - accuracy: 0.7578 - loss: 0.4918 - val_accuracy: 0.7600 - val_loss: 0.5025
# Epoch 8/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 200ms/step - accuracy: 0.7816 - loss: 0.4698 - val_accuracy: 0.7450 - val_loss: 0.5306
# Epoch 9/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 200ms/step - accuracy: 0.7825 - loss: 0.4602 - val_accuracy: 0.7675 - val_loss: 0.4728
# Epoch 10/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 198ms/step - accuracy: 0.7985 - loss: 0.4350 - val_accuracy: 0.7540 - val_loss: 0.5134
# Epoch 11/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 51s 201ms/step - accuracy: 0.8057 - loss: 0.4134 - val_accuracy: 0.7870 - val_loss: 0.4692
# Epoch 12/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 201ms/step - accuracy: 0.8031 - loss: 0.4219 - val_accuracy: 0.7870 - val_loss: 0.4892
# Epoch 13/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 201ms/step - accuracy: 0.8224 - loss: 0.3930 - val_accuracy: 0.7875 - val_loss: 0.4787
# Epoch 14/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 201ms/step - accuracy: 0.8303 - loss: 0.3799 - val_accuracy: 0.7910 - val_loss: 0.4734
# Epoch 15/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 201ms/step - accuracy: 0.8280 - loss: 0.3776 - val_accuracy: 0.7945 - val_loss: 0.4728
# Epoch 16/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 198ms/step - accuracy: 0.8341 - loss: 0.3657 - val_accuracy: 0.7945 - val_loss: 0.4746
# Epoch 17/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 197ms/step - accuracy: 0.8521 - loss: 0.3381 - val_accuracy: 0.7900 - val_loss: 0.4724
# Epoch 18/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 201ms/step - accuracy: 0.8540 - loss: 0.3373 - val_accuracy: 0.7690 - val_loss: 0.4988
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 51s 202ms/step - accuracy: 0.8508 - loss: 0.3378 - val_accuracy: 0.7950 - val_loss: 0.5081
# Epoch 20/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 51s 205ms/step - accuracy: 0.8638 - loss: 0.3106 - val_accuracy: 0.7745 - val_loss: 0.5336
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 204ms/step - accuracy: 0.8686 - loss: 0.2959 - val_accuracy: 0.7955 - val_loss: 0.4893
# Epoch 22/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 197ms/step - accuracy: 0.8733 - loss: 0.2898 - val_accuracy: 0.7990 - val_loss: 0.4936
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 201ms/step - accuracy: 0.8767 - loss: 0.2839 - val_accuracy: 0.7910 - val_loss: 0.5204
# Epoch 24/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 51s 202ms/step - accuracy: 0.8833 - loss: 0.2720 - val_accuracy: 0.8040 - val_loss: 0.4918
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 200ms/step - accuracy: 0.8897 - loss: 0.2616 - val_accuracy: 0.7620 - val_loss: 0.5942

# %% [markdown]
# ##Langkah 5 - Prediksi dengan 1 Citra
#
# Pada langkah ini, kita akan mencoba melakukan prediksi pada 1 citra anjing dan kucing.

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step

# %%
print(prediction)
# Out:
# dog
